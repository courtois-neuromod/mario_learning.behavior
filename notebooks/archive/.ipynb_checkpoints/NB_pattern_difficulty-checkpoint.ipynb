# %%
from mario_scenes.load_data import load_scenes_info
from mario_replays.load_data import load_replay_data
import os
import pandas as pd
import numpy as np
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load data

scenes_mastersheet = load_scenes_info(format='df')
# Drop Entry Point and Exit Point columns
scenes_mastersheet = scenes_mastersheet.drop(columns=['Entry point', 'Exit point', 'Valley', 'Checkpoint', 'Layout'])


df_list = []
sourcedata = '../../mario_learning.behavior/sourcedata/'
output_csv = '../outputdata/clips_metadata.csv'
if not os.path.exists(output_csv):    
    for clips_dir in os.listdir(sourcedata):
        if 'replays' not in clips_dir and '.' not in clips_dir: 
            print(clips_dir)
            sidecars_df = load_replay_data(os.path.join(sourcedata, clips_dir), type='metadata')
            
            if "StateClipCode" in sidecars_df.columns:
                sidecars_df = sidecars_df.rename(columns={"StateClipCode": "ClipCode"})
            df_list.append(sidecars_df)

    full_df = pd.concat(df_list)
    full_df.loc[full_df["Model"].isnull(), "Model"] = "human"
    full_df.to_csv(output_csv, index=False)
else:
    full_df = pd.read_csv(output_csv)
# Out:
# /tmp/ipykernel_13538/3073750027.py:25: DtypeWarning: Columns (1,6,26,27,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   full_df = pd.read_csv(output_csv)

# %%
# Split early and late part of the phases.
mask = full_df["Model"].eq("human")
med = (
    full_df.loc[mask]
           .groupby(["Subject", "Phase", "LevelFullName"])["ClipCode"]
           .transform("median")
)
full_df.loc[mask, "Phase_stage"] = np.where(
    full_df.loc[mask, "ClipCode"] < med,
    "Early",
    "Late"
)
clips_metadata = full_df

import pickle as pkl
with open('../outputdata/clusters.pkl', 'rb') as f:
    clusters = pkl.load(f)

full_df
# Out:
#                     Model                                      StateFileName  \
# 0         ppo_mario_ep-20  scene_clips/sub-01/ses-001/beh/savestates/sub-...
# 1         ppo_mario_ep-20  scene_clips/sub-01/ses-001/beh/savestates/sub-...
# 2         ppo_mario_ep-20  scene_clips/sub-01/ses-001/beh/savestates/sub-...
# 3         ppo_mario_ep-20  scene_clips/sub-01/ses-001/beh/savestates/sub-...
# 4         ppo_mario_ep-20  scene_clips/sub-01/ses-001/beh/savestates/sub-...
# ...                   ...                                                ...
# 336841  ppo_mario_ep-8000  scene_clips/sub-06/ses-025/beh/savestates/sub-...
# 336842  ppo_mario_ep-8000  scene_clips/sub-06/ses-025/beh/savestates/sub-...
# 336843  ppo_mario_ep-8000  scene_clips/sub-06/ses-025/beh/savestates/sub-...
# 336844  ppo_mario_ep-8000  scene_clips/sub-06/ses-025/beh/savestates/sub-...
# 336845  ppo_mario_ep-8000  scene_clips/sub-06/ses-025/beh/savestates/sub-...
#
# ...

# %%
def plot_cleared_by_pattern(clips_metadata, scenes_mastersheet, ax=None, sort=True, sort_by='rank', 
                             figsize=(12, 5), title="Average Cleared", palette="tab10", split_by=None,
                             clusters=None, cluster_id=20, legend_name=None, legend=True):
    """
    Plot average 'Cleared' per pattern (default) or per cluster (if clusters is provided).
    
    Parameters:
    - clips_metadata: pd.DataFrame
    - scenes_mastersheet: pd.DataFrame
    - ax: matplotlib axis
    - sort: bool, if False, disables sorting regardless of sort_by
    - sort_by: 'rank' (by avg cleared), 'name' (alphabetical), or None (original order)
    - figsize: tuple, used if ax is None
    - title: str, plot title
    - palette: color palette
    - split_by: 'Model' or 'Subject' or None
    - clusters: dict or None, if provided, use cluster-based grouping
    - cluster_id: int, which clustering to use from the dict
    """
    # Filter and prepare clips_metadata
    clips = clips_metadata.copy()
    clips = clips.dropna(subset=["World", "Level", "Scene", "Cleared"])
    clips["SceneKey"] = clips["World"].astype(int).astype(str) + "-" + \
                        clips["Level"].astype(int).astype(str) + "-" + \
                        clips["Scene"].astype(int).astype(str)
    clips["Cleared"] = pd.to_numeric(clips["Cleared"], errors='coerce')
    clips = clips.dropna(subset=["Cleared"])

    # Prepare scenes_mastersheet
    scenes = scenes_mastersheet.dropna(subset=["World", "Level", "Scene"]).copy()
    scenes["SceneKey"] = scenes["World"].astype(int).astype(str) + "-" + \
                         scenes["Level"].astype(int).astype(str) + "-" + \
                         scenes["Scene"].astype(int).astype(str)

    # Merge to get cleared per scene
    merged = pd.merge(clips, scenes[["SceneKey"]], on="SceneKey", how="inner")

    def determine_order(values, sort_by, label_name):
        if not sort:
            return values
        if sort_by == 'rank':
            return values.groupby(label_name)["Cleared"].mean().sort_values(ascending=False).index
        elif sort_by == 'name':
            return sorted(values[label_name].unique())
        else:
            return values[label_name].unique()

    if clusters is not None:
        # Cluster mode
        cluster_assignments = clusters[cluster_id]['index']
        scenes = scenes.reset_index(drop=True)
        scenes['Cluster'] = cluster_assignments

        merged = pd.merge(merged, scenes[['SceneKey', 'Cluster']], on='SceneKey', how='left')

        group_cols = ['Cluster']
        if split_by:
            group_cols.append(split_by)
        grouped = merged.groupby(group_cols)["Cleared"].mean().reset_index()

        order = determine_order(grouped, sort_by, "Cluster")

        if ax is None:
            fig, ax = plt.subplots(figsize=figsize)

        if split_by:
            sns.barplot(data=grouped, x="Cluster", y="Cleared", hue=split_by, order=order, ax=ax, palette=palette)
            ax.legend(title=split_by, bbox_to_anchor=(1.05, 1), loc='upper left')
        else:
            sns.barplot(data=grouped, x="Cluster", y="Cleared", order=order, ax=ax, color=sns.color_palette(palette)[0])
            legend_obj = ax.get_legend()
            if legend_obj is not None:
                legend_obj.remove()

        ax.set_xlabel("Cluster")
    else:
        # Pattern mode
        pattern_columns = scenes.columns[7:-1]
        clips_with_patterns = pd.merge(clips, scenes[["SceneKey"] + list(pattern_columns)], on="SceneKey", how="inner")

        melted = clips_with_patterns.melt(
            id_vars=["SceneKey", "Cleared"] + ([split_by] if split_by else []),
            value_vars=pattern_columns,
            var_name="Pattern", value_name="HasPattern"
        )
        melted = melted[melted["HasPattern"] == 1]

        group_cols = ["Pattern"]
        if split_by:
            group_cols.append(split_by)
        grouped = melted.groupby(group_cols)["Cleared"].mean().reset_index()

        order = determine_order(grouped, sort_by, "Pattern")

        if ax is None:
            fig, ax = plt.subplots(figsize=figsize)

        if split_by:
            sns.barplot(data=grouped, x="Pattern", y="Cleared", hue=split_by, order=order, ax=ax, palette=palette)
            ax.legend(title=split_by, bbox_to_anchor=(1.05, 1), loc='upper left')
        else:
            sns.barplot(data=grouped, x="Pattern", y="Cleared", order=order, ax=ax, color=sns.color_palette(palette)[0])
            legend = ax.get_legend()
            if legend is not None:
                legend.remove()

        ax.set_xlabel("Pattern")
    
    if legend_name:
        ax.legend(title=legend_name, bbox_to_anchor=(1.05, 1), loc='upper left')
    if not legend:
        ax.get_legend().remove()
        

    # Final plot styling
    ax.set_ylabel("Cleared")
    ax.set_title(title)
    ax.set_ylim(0, 1.05)
    ax.set_axisbelow(True)
    ax.yaxis.grid(True, linestyle='--', alpha=0.6)
    ax.xaxis.grid(False)
    if ax.get_xticklabels():
        ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
    plt.tight_layout()
    return ax

# %%
# Prepare the various filtered DFs

discovery_df = clips_metadata[clips_metadata['Phase'] == 'discovery']
practice_df = clips_metadata[clips_metadata['Phase'] == 'practice']

models_df = clips_metadata[clips_metadata['Model'] != 'human']
models_df['Model'] = models_df['Model'].str.replace('ppo_mario_', '')

humans_df = clips_metadata[clips_metadata['Model'] == 'human']
humans_df['Subject'] = 'sub-0' + humans_df['Subject'].astype(str)

phasesplit_df = clips_metadata.copy()
phasesplit_df = phasesplit_df[phasesplit_df['Model'] == 'human']
phasesplit_df.loc[phasesplit_df["Model"] == 'human', "Model"] = 'Humans ' + phasesplit_df['Phase'] + ' ' + phasesplit_df['Phase_stage']
# Out:
# /tmp/ipykernel_13538/4253726879.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   models_df['Model'] = models_df['Model'].str.replace('ppo_mario_', '')
# /tmp/ipykernel_13538/4253726879.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   humans_df['Subject'] = 'sub-0' + humans_df['Subject'].astype(str)

# %%
### learning per pattern, per subject

fig, ax = plt.subplots(figsize=(20, 4))
plot_cleared_by_pattern(humans_df, scenes_mastersheet, ax=ax, split_by='Subject', palette='Set2', sort=True, sort_by='name', title="", legend=False)
plt.savefig('../outputdata/figures/cleared_by_pattern_per_subject.png', dpi=300, transparent=True, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_13538/2727967223.py:123: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
### learning per pattern, per subject

fig, ax = plt.subplots(figsize=(20, 3))
plot_cleared_by_pattern(humans_df, scenes_mastersheet, ax=ax, split_by='Subject', palette='Set2', sort=True, sort_by='name', title="", clusters=clusters, cluster_id=20, legend=False)
plt.savefig('../outputdata/figures/cleared_by_cluster_per_subject.png', dpi=300, transparent=True, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_13538/2727967223.py:123: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
### learning per pattern, per model vs per subject phase
fig, ax = plt.subplots(figsize=(20, 4))
plot_cleared_by_pattern(models_df, scenes_mastersheet, ax=ax, split_by='Model', palette='magma', title="", sort_by='name', legend_name='PPO', legend=False)
plt.show()
# Out:
# /tmp/ipykernel_13538/2727967223.py:123: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
### learning per scene cluster, per model vs per subject phase
fig, ax = plt.subplots(figsize=(16, 3))
plot_cleared_by_pattern(phasesplit_df, scenes_mastersheet, ax=ax, split_by='Model', palette='viridis', clusters=clusters, title="Average Cleared by Cluster and training phase", cluster_id=20, sort=True, sort_by='name')
plt.show()
# Out:
# /tmp/ipykernel_13538/2727967223.py:123: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
fig, ax = plt.subplots(figsize=(16, 3))
plot_cleared_by_pattern(models_df, scenes_mastersheet, ax=ax, split_by='Model', palette='magma', clusters=clusters, title="Average Cleared by Cluster and Model", cluster_id=20, sort=True, sort_by='name')
plt.show()
# Out:
# /tmp/ipykernel_13538/2727967223.py:123: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
fig, ax = plt.subplots(figsize=(16, 3))
plot_cleared_by_pattern(models_df, scenes_mastersheet, ax=ax, split_by='Model', palette='magma', title="", cluster_id=20, sort=True, sort_by='name', legend=False)
plt.savefig('../outputdata/figures/cleared_by_pattern_per_model.png', dpi=300, transparent=True, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_13538/2727967223.py:123: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
### learning per scene cluster, per model vs per subject phase
fig, ax = plt.subplots(figsize=(16, 3))
plot_cleared_by_pattern(phasesplit_df, scenes_mastersheet, ax=ax, split_by='Model', palette='viridis', title="Average Cleared by Cluster and training phase", cluster_id=20, sort=True, sort_by='name', legend=False)
plt.show()
# Out:
# /tmp/ipykernel_13538/2727967223.py:123: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
### learning per scene cluster, per model vs per subject phase
fig, axes = plt.subplots(2, 1, figsize=(16, 6), sharex=True)
axes = axes.flatten()

plot_cleared_by_pattern(phasesplit_df, scenes_mastersheet, ax=axes[0], split_by='Model', palette='viridis', title="", cluster_id=20, sort=True, sort_by='name', legend=False)


plot_cleared_by_pattern(models_df, scenes_mastersheet, ax=axes[1], split_by='Model', palette='magma', title="", cluster_id=20, sort=True, sort_by='name', legend=False)


plt.savefig('../outputdata/figures/cleared_by_pattern_per_model.png', dpi=300, transparent=True, bbox_inches='tight')
plt.show()
# Out:
# /tmp/ipykernel_67895/2727967223.py:123: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
#full_df.to_csv('../outputdata/clips_metadata_full.csv', index=False)

models_df["SceneFullName"] = models_df["World"].astype(int).astype(str) + "-" + \
                        models_df["Level"].astype(int).astype(str) + "-" + \
                        models_df["Scene"].astype(int).astype(str)
humans_df["SceneFullName"] = humans_df["World"].astype(int).astype(str) + "-" + \
                        humans_df["Level"].astype(int).astype(str) + "-" + \
                        humans_df["Scene"].astype(int).astype(str)
humans_df['Learning_Phase'] = humans_df['Phase_stage'] + ' ' + humans_df['Phase']

scenes = scenes_mastersheet.dropna(subset=["World", "Level", "Scene"]).copy()
scenes["SceneFullName"] = scenes["World"].astype(int).astype(str) + "-" + \
                        scenes["Level"].astype(int).astype(str) + "-" + \
                        scenes["Scene"].astype(int).astype(str)


# For each pattern in scenes (from Enemy to Waterworld columns), make a list of SceneFullNames that have that pattern
pattern_columns = scenes.columns[7:-1]
scenes_in_pattern = {}
for pattern in pattern_columns:
    scenes_in_pattern[pattern] = scenes[scenes[pattern] == 1]['SceneFullName'].tolist()


scenes_in_pattern.keys()

# Add a column containing 0's for each key in scenes_in_pattern. The column name must be Pattern_<pattern>
for pattern in scenes_in_pattern.keys():
    humans_df[f'Pattern_{pattern}'] = 0
    models_df[f'Pattern_{pattern}'] = 0

# For each row in humans_df, check if the SceneFullName is in the list of scenes for each pattern. If it is, set the corresponding Pattern_<pattern> column to 1
for index, row in humans_df.iterrows():
    for pattern, scenes_list in scenes_in_pattern.items():
        if row['SceneFullName'] in scenes_list:
            humans_df.at[index, f'Pattern_{pattern}'] = 1
for index, row in models_df.iterrows():
    for pattern, scenes_list in scenes_in_pattern.items():
        if row['SceneFullName'] in scenes_list:
            models_df.at[index, f'Pattern_{pattern}'] = 1
pattern_columns = [f'Pattern_{pattern}' for pattern in pattern_columns]
pattern_learning_df = pd.concat([humans_df, models_df])

pattern_learning_df.to_csv('../outputdata/clips_metadata_with_patterns.csv', index=False)
# Out:
# /tmp/ipykernel_13538/747960294.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   models_df["SceneFullName"] = models_df["World"].astype(int).astype(str) + "-" + \
# /tmp/ipykernel_13538/747960294.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   humans_df["SceneFullName"] = humans_df["World"].astype(int).astype(str) + "-" + \
# /tmp/ipykernel_13538/747960294.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# ## Create graphs with learning metric early training*(late training - early training)

# %%
# For both humans_df and models_df:
# Create a new column named "Training_stage", that will be for humans 0 if Phase is discovery and Phase_stage is Early, 1 if Phase is practice and Phase_stage is Late.
# For models, it will be 0 if model is ep-20 and 1 if model is ep-8000.
humans_df['Training_stage'] = np.where(
    (humans_df['Phase'] == 'discovery') & (humans_df['Phase_stage'] == 'Early'), 0,
    np.where(
        (humans_df['Phase'] == 'practice') & (humans_df['Phase_stage'] == 'Late'), 1,
        np.nan
    )
)
models_df['Training_stage'] = np.where(
    models_df['Model'] == 'ep-20', 0,
    np.where(
        models_df['Model'] == 'ep-8000', 1,
        np.nan
    )
)
models_df = models_df.dropna(subset=['Training_stage'])
humans_df = humans_df.dropna(subset=['Training_stage'])


models_df["SceneFullName"] = models_df["World"].astype(int).astype(str) + "-" + \
                        models_df["Level"].astype(int).astype(str) + "-" + \
                        models_df["Scene"].astype(int).astype(str)
humans_df["SceneFullName"] = humans_df["World"].astype(int).astype(str) + "-" + \
                        humans_df["Level"].astype(int).astype(str) + "-" + \
                        humans_df["Scene"].astype(int).astype(str)

scenes = scenes_mastersheet.dropna(subset=["World", "Level", "Scene"]).copy()
scenes["SceneFullName"] = scenes["World"].astype(int).astype(str) + "-" + \
                        scenes["Level"].astype(int).astype(str) + "-" + \
                        scenes["Scene"].astype(int).astype(str)


# Group and average values by SceneFullName and Training_stage
grouped_humans = humans_df.groupby(['SceneFullName', 'Training_stage'])['Cleared'].mean().unstack().reset_index()

# Compute learning metric: 0*(1 - 0)
grouped_humans['Learning_metric'] = grouped_humans[0] * (grouped_humans[1] - grouped_humans[0])

grouped_models = models_df.groupby(['SceneFullName', 'Training_stage'])['Cleared'].mean().unstack().reset_index()

# Compute learning metric: 0*(1 - 0)
grouped_models['Learning_metric'] = grouped_models[0] * (grouped_models[1] - grouped_models[0])

# For each pattern in scenes (from Enemy to Waterworld columns), make a list of SceneFullNames that have that pattern
pattern_columns = scenes.columns[7:-1]
scenes_in_pattern = {}
for pattern in pattern_columns:
    scenes_in_pattern[pattern] = scenes[scenes[pattern] == 1]['SceneFullName'].tolist()


# Now, for each pattern in scenes_in_pattern, get the average learning metric for humans (each subject separately) and models, and group that in a single dataframe
# Thus, I should obtain a dataframe with the columns : Pattern, Subject (sub-01, sub-02, etc or PPO), Learning_metric
pattern_learning_list = []
for pattern, scene_list in scenes_in_pattern.items():
    humans_avg_0 = grouped_humans[grouped_humans['SceneFullName'].isin(scene_list)][0].mean()
    humans_avg_1 = grouped_humans[grouped_humans['SceneFullName'].isin(scene_list)][1].mean()
    humans_avg_learning = humans_avg_0 * (humans_avg_1 - humans_avg_0)
    
    pattern_learning_list.append({
        'Pattern': pattern,
        'Subject': 'Humans',
        'Learning_metric': humans_avg_learning
    })
    models_avg_0 = grouped_models[grouped_models['SceneFullName'].isin(scene_list)][0].mean()
    models_avg_1 = grouped_models[grouped_models['SceneFullName'].isin(scene_list)][1].mean()
    models_avg_learning = models_avg_0 * (models_avg_1 - models_avg_0)
    pattern_learning_list.append({
        'Pattern': pattern,
        'Subject': 'PPO',
        'Learning_metric': models_avg_learning
    })

pattern_learning_df = pd.DataFrame(pattern_learning_list)

humans_color = sns.color_palette("viridis", 256)[156]
models_color = sns.color_palette("magma", 256)[156]
palette = [humans_color, models_color]

# Order Pattern by alphabetical order
pattern_learning_df['Pattern'] = pd.Categorical(pattern_learning_df['Pattern'], categories=sorted(pattern_learning_df['Pattern'].unique()), ordered=True)
pattern_learning_df = pattern_learning_df.sort_values('Pattern')

plt.figure(figsize=(12, 5))
sns.barplot(data=pattern_learning_df, x='Pattern', y='Learning_metric', hue='Subject', palette=palette)
plt.title('Learning Metric by Pattern and Subject/Model')
plt.xticks(rotation=90)
plt.tight_layout()
# Out:
# /tmp/ipykernel_67895/674521331.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   humans_df['Training_stage'] = np.where(
# /tmp/ipykernel_67895/674521331.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   models_df['Training_stage'] = np.where(

# %%
# For both humans_df and models_df:
# Create a new column named "Training_stage", that will be for humans 0 if Phase is discovery and Phase_stage is Early, 1 if Phase is practice and Phase_stage is Late.
# For models, it will be 0 if model is ep-20 and 1 if model is ep-8000.
humans_df['Training_stage'] = np.where(
    (humans_df['Phase'] == 'discovery') & (humans_df['Phase_stage'] == 'Early'), 0,
    np.where(
        (humans_df['Phase'] == 'practice') & (humans_df['Phase_stage'] == 'Late'), 1,
        np.nan
    )
)
models_df['Training_stage'] = np.where(
    models_df['Model'] == 'ep-20', 0,
    np.where(
        models_df['Model'] == 'ep-8000', 1,
        np.nan
    )
)
models_df = models_df.dropna(subset=['Training_stage'])
humans_df = humans_df.dropna(subset=['Training_stage'])


models_df["SceneFullName"] = models_df["World"].astype(int).astype(str) + "-" + \
                        models_df["Level"].astype(int).astype(str) + "-" + \
                        models_df["Scene"].astype(int).astype(str)
humans_df["SceneFullName"] = humans_df["World"].astype(int).astype(str) + "-" + \
                        humans_df["Level"].astype(int).astype(str) + "-" + \
                        humans_df["Scene"].astype(int).astype(str)

scenes = scenes_mastersheet.dropna(subset=["World", "Level", "Scene"]).copy()
scenes["SceneFullName"] = scenes["World"].astype(int).astype(str) + "-" + \
                        scenes["Level"].astype(int).astype(str) + "-" + \
                        scenes["Scene"].astype(int).astype(str)


# Group and average values by SceneFullName and Training_stage
grouped_humans = humans_df.groupby(['SceneFullName', 'Subject', 'Training_stage'])['Cleared'].mean().unstack().reset_index()

# Compute learning metric: 0*(1 - 0)
grouped_humans['Learning_metric'] = grouped_humans[0] * (grouped_humans[1] - grouped_humans[0])

grouped_models = models_df.groupby(['SceneFullName', 'Training_stage'])['Cleared'].mean().unstack().reset_index()

# Compute learning metric: 0*(1 - 0)
grouped_models['Learning_metric'] = grouped_models[0] * (grouped_models[1] - grouped_models[0])

# For each pattern in scenes (from Enemy to Waterworld columns), make a list of SceneFullNames that have that pattern
pattern_columns = scenes.columns[7:-1]
scenes_in_pattern = {}
for pattern in pattern_columns:
    scenes_in_pattern[pattern] = scenes[scenes[pattern] == 1]['SceneFullName'].tolist()


# Now, for each pattern in scenes_in_pattern, get the average learning metric for humans (each subject separately) and models, and group that in a single dataframe
# Thus, I should obtain a dataframe with the columns : Pattern, Subject (sub-01, sub-02, etc or PPO), Learning_metric
pattern_learning_list = []


for pattern, scene_list in scenes_in_pattern.items():
    humans_avg_0 = grouped_humans[grouped_humans['SceneFullName'].isin(scene_list)].groupby('Subject')[0].mean()
    humans_avg_1 = grouped_humans[grouped_humans['SceneFullName'].isin(scene_list)].groupby('Subject')[1].mean()
    humans_avg_learning = humans_avg_0 * (humans_avg_1 - humans_avg_0)
    for idx, val in enumerate(humans_avg_learning):
        subject = humans_avg_learning.index[idx]
        pattern_learning_list.append({
            'Pattern': pattern,
            'Subject': subject,
            'Learning_metric': val,
            'Early_training': humans_avg_0[idx],
            'Late_training': humans_avg_1[idx] 
        })
    
    models_avg_0 = grouped_models[grouped_models['SceneFullName'].isin(scene_list)][0].mean()
    models_avg_1 = grouped_models[grouped_models['SceneFullName'].isin(scene_list)][1].mean()
    models_avg_learning = models_avg_0 * (models_avg_1 - models_avg_0)
    pattern_learning_list.append({
        'Pattern': pattern,
        'Subject': 'PPO',
        'Learning_metric': models_avg_learning,
        'Early_training': models_avg_0,
        'Late_training': models_avg_1
    })

pattern_learning_df = pd.DataFrame(pattern_learning_list)
pattern_learning_df.to_csv('../outputdata/pattern_learning_metrics_averaged.csv', index=False)

humans_color = sns.color_palette("viridis", 256)[156]
models_color = sns.color_palette("magma", 256)[156]
palette = [humans_color, models_color]

# Order Pattern by alphabetical order
pattern_learning_df['Pattern'] = pd.Categorical(pattern_learning_df['Pattern'], categories=sorted(pattern_learning_df['Pattern'].unique()), ordered=True)
pattern_learning_df = pattern_learning_df.sort_values('Pattern')

plt.figure(figsize=(12, 5))
sns.barplot(data=pattern_learning_df, x='Pattern', y='Learning_metric', hue='Subject')#, palette=palette)
plt.title('Learning Metric by Pattern and Subject/Model')
plt.xticks(rotation=90)
plt.tight_layout()
# Out:
# /tmp/ipykernel_13538/138015609.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   humans_df['Training_stage'] = np.where(
# /tmp/ipykernel_13538/138015609.py:68: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   'Early_training': humans_avg_0[idx],
# /tmp/ipykernel_13538/138015609.py:69: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# ...

# %%
# Out:
# Subject
# sub-01    0.062900
# sub-02    0.068365
# sub-03    0.063183
# sub-05    0.012364
# sub-06    0.033873
# dtype: float64

# %%
pattern_learning_df
# Out:
#            Pattern Subject  Learning_metric
# 11         2-Horde     PPO         0.016611
# 10         2-Horde  sub-06         0.036932
# 8          2-Horde  sub-03         0.016555
# 7          2-Horde  sub-02         0.095694
# 6          2-Horde  sub-01         0.058724
# ..             ...     ...              ...
# 42   Variable gaps  sub-01         0.103336
# 162     Waterworld  sub-03              NaN
# 163     Waterworld  sub-05              NaN
# 164     Waterworld  sub-06         0.187500
# 165     Waterworld     PPO        -0.004394
#
# [166 rows x 3 columns]

# %%
# Out:
# Training_stage SceneFullName       0.0       1.0  Learning_metric
# 0                      1-1-0  1.000000  1.000000         0.000000
# 1                      1-1-1  0.544910  0.886228         0.185987
# 2                     1-1-10  1.000000  0.975000        -0.025000
# 3                     1-1-11  0.642857  0.701299         0.037570
# 4                     1-1-12  1.000000  1.000000         0.000000
# ..                       ...       ...       ...              ...
# 303                    8-3-5  0.756654  0.726236        -0.023016
# 304                    8-3-6  0.427984  0.510288         0.035225
# 305                    8-3-7  0.531469  0.566434         0.018583
# 306                    8-3-8  0.319328  0.319328         0.000000
# 307                    8-3-9  0.284091  0.159091        -0.035511
#
# [308 rows x 4 columns]
